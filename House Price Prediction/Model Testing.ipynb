# %%
from joblib import dump,load
import numpy as np
model = load('House_Price_Prediction.joblib')

# %%
features1 = np.array([[-0.44352175,  3.12628155, -1.35893781, -0.27288841, -1.0542567 ,
        0.49785088, -1.3938808 ,  2.19312325, -0.65766683, -0.78557904,
       -0.69277865,  0.39131918, -0.94116739]])
model.predict(features1)
# Out:
# array([25.339])

# %%
features2 = np.array([[-0.44352175,  2.12628155, -1.35893781, -0.27288841, -1.0542567 ,
        0.89785088, -1.3938808 ,  2.19312325, -0.65766683, -0.98557904,
       -0.69277865,  0.39131918, -0.44116739]])
model.predict(features2)
# Out:
# array([28.291])
